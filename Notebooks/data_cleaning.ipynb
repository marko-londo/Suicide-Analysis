# %%
import pandas as pd

# %%
# Combining and cleaning suicide by state by age data 

df1 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_1999.csv").assign(Year="1999")
df2 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2000.csv").assign(Year="2000")
df3 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2001.csv").assign(Year="2001")
df4 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2002.csv").assign(Year="2002")
df5 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2003.csv").assign(Year="2003")
df6 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2004.csv").assign(Year="2004")
df7 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2005.csv").assign(Year="2005")
df8 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2006.csv").assign(Year="2006")
df9 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2007.csv").assign(Year="2007")
df10 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2008.csv").assign(Year="2008")
df11 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2009.csv").assign(Year="2009")
df12 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2010.csv").assign(Year="2010")
df13 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2011.csv").assign(Year="2011")
df14 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2012.csv").assign(Year="2012")
df15 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2013.csv").assign(Year="2013")
df16 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2014.csv").assign(Year="2014")
df17 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2015.csv").assign(Year="2015")
df18 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2016.csv").assign(Year="2016")
df19 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2017.csv").assign(Year="2017")
df20 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2018.csv").assign(Year="2018")
df21 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2019.csv").assign(Year="2019")
df22 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2020.csv").assign(Year="2020")
df23 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2021.csv").assign(Year="2021")


dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16,
       df17, df18, df19, df20, df21, df22, df23]

for df in dfs:
    df.set_index("Year", inplace=True, drop=True)
    sum_values = df.iloc[1:].sum(numeric_only=True)
    df.iloc[0] = df.iloc[0].fillna(sum_values)
    column_sums = df.iloc[:, :-1].sum(axis=1, numeric_only=True)
    df["Total"].fillna(column_sums, inplace=True)

suicides_by_age = pd.concat(dfs)
suicides_by_age.drop("0 to 17", axis=1, inplace=True)
suicides_by_age.dropna(subset=["Location"], inplace=True)
suicides_by_age.dropna(inplace=True)
suicides_by_age.to_csv("suicides_by_state_by_age_1999-2021.csv")

# %%
# Extracting US suicides from World suicides

world_suicides = pd.read_csv(r"../Resources/Originals/world_suicides_1985-2016.csv")
world_suicides.drop(["Population", "Country-Year"], axis=1, inplace=True)
us_suicides_8516 = world_suicides[world_suicides["Country"] == "United States"].copy()
us_suicides_8516.to_csv("us_suicides_1985-2016(master).csv")

# Cleaning US suicide data from 1985-2016, removing unnecessary columns

us_suicides_8516.drop(["Country"], axis=1, inplace=True)

# Extracting yearly total suicides for the US from 1985-2013

us_suicides_8513 =  us_suicides_8516.drop(["Sex", "Age", "Suicides per 100k", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1)
us_suicides_8513 = us_suicides_8513.groupby("Year")["Number of Suicides"].sum().reset_index()
us_suicides_8513 = us_suicides_8513[~(us_suicides_8513["Year"] == 2014)]
us_suicides_8513 = us_suicides_8513[~(us_suicides_8513["Year"] == 2015)]

# %%
# Extracting yearly total suicides for the US from 2014-2021

state_suicides_0521 = pd.read_csv(
    r"../Resources/Originals/state_suicides_2005-2021.csv"
)
state_suicides_0521.drop(["URL", "RATE"], axis=1, inplace=True)
state_suicides_0521["DEATHS"] = state_suicides_0521["DEATHS"].str.replace(",", "")
state_suicides_0521["DEATHS"] = state_suicides_0521["DEATHS"].str.replace('"', "")
state_suicides_0521["DEATHS"] = pd.to_numeric(
    state_suicides_0521["DEATHS"], errors="coerce"
)
us_suicides_0521 = state_suicides_0521.groupby("YEAR")["DEATHS"].sum().reset_index()
us_suicides_0521 = us_suicides_0521[~(us_suicides_0521["YEAR"] == 2005)]
column_mapping = {"YEAR": "Year", "DEATHS": "Number of Suicides"}
us_suicides_0521 = us_suicides_0521.rename(columns=column_mapping)

# %%
# Concatenating the dataframes to account for missing data

us_suicides_8521 = pd.concat([us_suicides_8513, us_suicides_0521]).set_index("Year")
us_suicides_8521.to_csv("us_suicides_1985-2021.csv")

# %%
# Extracting Russia suicides from World suicides

russia_suicides_8516 = world_suicides[world_suicides["Country"] == "Russian Federation"].copy()
russia_suicides_8516.to_csv("russia_suicides_1985-2016(master).csv")

# Cleaning Russia suicide data from 1985-2016, removing unnecessary columns

russia_suicides_8516.drop(["Country"], axis=1, inplace=True)

# Extracting yearly total suicides for the Russia from 1985-2016

russia_suicides_8516 =  russia_suicides_8516.drop(["Sex", "Age", "Suicides per 100k", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1)
russia_suicides_8516 = russia_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
russia_suicides_8516.to_csv("russia_suicides_1985-2016.csv")

# %%
# Extracting Japan suicides from World suicides

japan_suicides_8516 = world_suicides[world_suicides["Country"] == "Japan"].copy()
japan_suicides_8516.to_csv("japan_suicides_1985-2016(master).csv")

# Cleaning Japan suicide data from 1985-2016, removing unnecessary columns

japan_suicides_8516.drop(["Country"], axis=1, inplace=True)

# Extracting yearly total suicides for the Japan from 1985-2016

japan_suicides_8516 =  japan_suicides_8516.drop(["Sex", "Age", "Suicides per 100k", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1)
japan_suicides_8516 = japan_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
japan_suicides_8516.to_csv("japan_suicides_1985-2016.csv")

# %%
# Extracting canada suicides from World suicides

canada_suicides_8516 = world_suicides[world_suicides["Country"] == "Canada"].copy()
canada_suicides_8516.to_csv("canada_suicides_1985-2016(master).csv")

# Cleaning canada suicide data from 1985-2016, removing unnecessary columns

canada_suicides_8516.drop(["Country"], axis=1, inplace=True)

# Extracting yearly total suicides for the canada from 1985-2016

canada_suicides_8516 =  canada_suicides_8516.drop(["Sex", "Age", "Suicides per 100k", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1)
canada_suicides_8516 = canada_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
canada_suicides_8516.to_csv("canada_suicides_1985-2016.csv")

# %%
# Extracting germany suicides from World suicides

germany_suicides_8516 = world_suicides[world_suicides["Country"] == "Germany"].copy()
germany_suicides_8516.to_csv("germany_suicides_1985-2016(master).csv")

# Cleaning germany suicide data from 1985-2016, removing unnecessary columns

germany_suicides_8516.drop(["Country"], axis=1, inplace=True)

# Extracting yearly total suicides for the germany from 1985-2016

germany_suicides_8516 =  germany_suicides_8516.drop(["Sex", "Age", "Suicides per 100k", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1)
germany_suicides_8516 = germany_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
germany_suicides_8516.to_csv("germany_suicides_1985-2016.csv")

# %%
# Cleaning Untreated Mental Illness data

untreated_mental_illness = pd.read_csv(
    r"../Resources/Originals/untreated_mental_illness_in_adults_2018-2019.csv"
)
total_untreated_mental_illness = untreated_mental_illness[
    untreated_mental_illness["Location"] == "United States"
].copy()
states_untreated_mental_illness = untreated_mental_illness[
    ~(untreated_mental_illness["Location"] == "United States")
]
total_untreated_mental_illness.set_index("Location", inplace=True)
states_untreated_mental_illness.set_index("Location", inplace=True)
total_untreated_mental_illness = total_untreated_mental_illness * 100
total_untreated_mental_illness = total_untreated_mental_illness.round(2)
states_untreated_mental_illness = states_untreated_mental_illness * 100
states_untreated_mental_illness = states_untreated_mental_illness.round(2)
states_untreated_mental_illness.to_csv(
    "untreated_mental_illness_by_state_2018-2019.csv"
)
total_untreated_mental_illness.to_csv("untreated_mental_illness_total_2018-2019.csv")

# %%
# Creating dataframe for 988 Lifeline Performance Metrics (sourced from https://www.samhsa.gov/find-help/988/performance-metrics)

data = {
    "Routed Calls": [
        262920,
        242995,
        243417,
        226634,
        248634,
        241555,
        222285,
        230928,
        239135,
        256398,
        245905,
    ],
    "Routed Chats": [
        68507,
        61082,
        61146,
        59225,
        71058,
        70616,
        72134,
        68425,
        66128,
        64115,
        75441,
    ],
    "Routed Texts": [
        71067,
        64859,
        64259,
        60365,
        64379,
        59484,
        52922,
        49992,
        45366,
        40627,
        33279,
    ],
    "Total Routed": [
        402494,
        368936,
        371822,
        346224,
        384071,
        371655,
        347341,
        349345,
        350629,
        361140,
        354625,
    ],
    "Total Answered Percentage": [93, 92, 92, 92, 91, 91, 92, 91, 88, 88, 84],
}

index = [
    "May 2023",
    "April 2023",
    "March 2023",
    "February 2023",
    "January 2023",
    "December 2022",
    "November 2022",
    "October 2022",
    "September 2022",
    "August 2022",
    "July 2022",
]

df = pd.DataFrame(data, index=index)
df.to_csv("988_performance_metrics.csv")
