# %%
import pandas as pd

# %%
# Creating dataframe for 988 Lifeline Performance Metrics (sourced from https://www.samhsa.gov/find-help/988/performance-metrics)

data = {
    "Routed Calls": [
        262920,
        242995,
        243417,
        226634,
        248634,
        241555,
        222285,
        230928,
        239135,
        256398,
        245905,
    ],
    "Routed Chats": [
        68507,
        61082,
        61146,
        59225,
        71058,
        70616,
        72134,
        68425,
        66128,
        64115,
        75441,
    ],
    "Routed Texts": [
        71067,
        64859,
        64259,
        60365,
        64379,
        59484,
        52922,
        49992,
        45366,
        40627,
        33279,
    ],
    "Total Routed": [
        402494,
        368936,
        371822,
        346224,
        384071,
        371655,
        347341,
        349345,
        350629,
        361140,
        354625,
    ],
    "Total Answered Percentage": [93, 92, 92, 92, 91, 91, 92, 91, 88, 88, 84],
}

index = [
    "May 2023",
    "April 2023",
    "March 2023",
    "February 2023",
    "January 2023",
    "December 2022",
    "November 2022",
    "October 2022",
    "September 2022",
    "August 2022",
    "July 2022",
]

df = pd.DataFrame(data, index=index)
# df.to_csv("988_performance_metrics.csv")

# %%
# Combining and cleaning suicide by state by age data

df1 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_1999.csv").assign(
    Year="1999"
)
df2 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2000.csv").assign(
    Year="2000"
)
df3 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2001.csv").assign(
    Year="2001"
)
df4 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2002.csv").assign(
    Year="2002"
)
df5 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2003.csv").assign(
    Year="2003"
)
df6 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2004.csv").assign(
    Year="2004"
)
df7 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2005.csv").assign(
    Year="2005"
)
df8 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2006.csv").assign(
    Year="2006"
)
df9 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2007.csv").assign(
    Year="2007"
)
df10 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2008.csv").assign(
    Year="2008"
)
df11 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2009.csv").assign(
    Year="2009"
)
df12 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2010.csv").assign(
    Year="2010"
)
df13 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2011.csv").assign(
    Year="2011"
)
df14 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2012.csv").assign(
    Year="2012"
)
df15 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2013.csv").assign(
    Year="2013"
)
df16 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2014.csv").assign(
    Year="2014"
)
df17 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2015.csv").assign(
    Year="2015"
)
df18 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2016.csv").assign(
    Year="2016"
)
df19 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2017.csv").assign(
    Year="2017"
)
df20 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2018.csv").assign(
    Year="2018"
)
df21 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2019.csv").assign(
    Year="2019"
)
df22 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2020.csv").assign(
    Year="2020"
)
df23 = pd.read_csv(r"../Resources/Originals/suicide_by_state_by_age_2021.csv").assign(
    Year="2021"
)


dfs = [
    df1,
    df2,
    df3,
    df4,
    df5,
    df6,
    df7,
    df8,
    df9,
    df10,
    df11,
    df12,
    df13,
    df14,
    df15,
    df16,
    df17,
    df18,
    df19,
    df20,
    df21,
    df22,
    df23,
]

# Iterate over each dataframe in the list 'dfs'
for df in dfs:
    # Set the 'Year' column as the index of the dataframe
    df.set_index("Year", inplace=True, drop=True)

    # Calculate the sum of numeric values in each row, starting from the second row
    sum_values = df.iloc[1:].sum(numeric_only=True)

    # Replace missing values in the first row with the calculated sum values
    df.iloc[0] = df.iloc[0].fillna(sum_values)

    # Calculate the sum of values in each row, excluding the last column
    column_sums = df.iloc[:, :-1].sum(axis=1, numeric_only=True)

    # Replace missing values in the 'Total' column with the calculated column sums
    df["Total"].fillna(column_sums, inplace=True)

# Concatenate all the dataframes in the list 'dfs' into a single dataframe
suicides_by_age = pd.concat(dfs)

# Remove the '0 to 17' column from the 'suicides_by_age' dataframe
suicides_by_age.drop("0 to 17", axis=1, inplace=True)

# Remove rows with missing values in the 'Location' column from the 'suicides_by_age' dataframe
suicides_by_age.dropna(subset=["Location"], inplace=True)

state_to_abbreviation = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY"
}
suicides_by_age['45 to 54'] = suicides_by_age['Total'] - (suicides_by_age['18 to 24'] + suicides_by_age['25 to 34'] + suicides_by_age['35 to 44'] + suicides_by_age['55+'])
suicides_by_age['Location'] = suicides_by_age['Location'].replace(state_to_abbreviation)
suicides_by_age = suicides_by_age[suicides_by_age['Location'] != "United States"]
suicides_by_age = suicides_by_age[suicides_by_age['Location'] != "District of Columbia"]
# suicides_by_age.to_csv("suicides_by_state_by_age_1999-2021.csv")
state_pop2000s = pd.read_csv(r"../Resources/Originals/state-population.csv")
state_pop1019 = pd.read_csv(r"../Resources/Originals/nst-est2019-alldata.csv")
state_pop1019['NAME'] = state_pop1019['NAME'].replace(state_to_abbreviation)
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "United States"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "Northeast Region"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "Midwest Region"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "South Region"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "West Region"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "District of Columbia"]
state_pop1019 = state_pop1019[state_pop1019['NAME'] != "Puerto Rico"]
state_pop1019 = state_pop1019.drop(["SUMLEV", "REGION", "DIVISION", "STATE", "CENSUS2010POP", "ESTIMATESBASE2010", "NPOPCHG_2010", "NPOPCHG_2011", "NPOPCHG_2012", "NPOPCHG_2013", "NPOPCHG_2014", "NPOPCHG_2015", "NPOPCHG_2016", "NPOPCHG_2017", "NPOPCHG_2018", "NPOPCHG_2019", "BIRTHS2010", "BIRTHS2011", "BIRTHS2012", "BIRTHS2013", "BIRTHS2014", "BIRTHS2015", "BIRTHS2016", "BIRTHS2017", "BIRTHS2018", "BIRTHS2019", "DEATHS2010", "DEATHS2011", "DEATHS2012", "DEATHS2013", "DEATHS2014", "DEATHS2015", "DEATHS2016", "DEATHS2017", "DEATHS2018", "DEATHS2019", "NATURALINC2010", "NATURALINC2011", "NATURALINC2012", "NATURALINC2013", "NATURALINC2014", "NATURALINC2015", "NATURALINC2016", "NATURALINC2017", "NATURALINC2018", "NATURALINC2019", "INTERNATIONALMIG2010", "INTERNATIONALMIG2011", "INTERNATIONALMIG2012", "INTERNATIONALMIG2013", "INTERNATIONALMIG2014", "INTERNATIONALMIG2015", "INTERNATIONALMIG2016", "INTERNATIONALMIG2017", "INTERNATIONALMIG2018", "INTERNATIONALMIG2019", "DOMESTICMIG2010", "DOMESTICMIG2011", "DOMESTICMIG2012", "DOMESTICMIG2013", "DOMESTICMIG2014", "DOMESTICMIG2015", "DOMESTICMIG2016", "DOMESTICMIG2017", "DOMESTICMIG2018", "DOMESTICMIG2019", "NETMIG2010", "NETMIG2011", "NETMIG2012", "NETMIG2013", "NETMIG2014", "NETMIG2015", "NETMIG2016", "NETMIG2017", "NETMIG2018", "NETMIG2019", "RESIDUAL2010", "RESIDUAL2011", "RESIDUAL2012", "RESIDUAL2013", "RESIDUAL2014", "RESIDUAL2015", "RESIDUAL2016", "RESIDUAL2017", "RESIDUAL2018", "RESIDUAL2019", "RBIRTH2011", "RBIRTH2012", "RBIRTH2013", "RBIRTH2014", "RBIRTH2015", "RBIRTH2016", "RBIRTH2017", "RBIRTH2018", "RBIRTH2019", "RDEATH2011", "RDEATH2012", "RDEATH2013", "RDEATH2014", "RDEATH2015", "RDEATH2016", "RDEATH2017", "RDEATH2018", "RDEATH2019", "RNATURALINC2011", "RNATURALINC2012", "RNATURALINC2013", "RNATURALINC2014", "RNATURALINC2015", "RNATURALINC2016", "RNATURALINC2017", "RNATURALINC2018", "RNATURALINC2019", "RINTERNATIONALMIG2011", "RINTERNATIONALMIG2012", "RINTERNATIONALMIG2013", "RINTERNATIONALMIG2014", "RINTERNATIONALMIG2015", "RINTERNATIONALMIG2016", "RINTERNATIONALMIG2017", "RINTERNATIONALMIG2018", "RINTERNATIONALMIG2019", "RDOMESTICMIG2011", "RDOMESTICMIG2012", "RDOMESTICMIG2013", "RDOMESTICMIG2014", "RDOMESTICMIG2015", "RDOMESTICMIG2016", "RDOMESTICMIG2017", "RDOMESTICMIG2018", "RDOMESTICMIG2019", "RNETMIG2011", "RNETMIG2012", "RNETMIG2013", "RNETMIG2014", "RNETMIG2015", "RNETMIG2016", "RNETMIG2017", "RNETMIG2018", "RNETMIG2019"], axis=1)
state_pop1019 = state_pop1019.rename(columns={"NAME": "Location", "POPESTIMATE2010": "2010", "POPESTIMATE2011": "2011", "POPESTIMATE2012": "2012", "POPESTIMATE2013": "2013", "POPESTIMATE2014": "2014", "POPESTIMATE2015": "2015", "POPESTIMATE2016": "2016", "POPESTIMATE2017": "2017", "POPESTIMATE2018": "2018", "POPESTIMATE2019": "2019"}
)
state_pop2000s = state_pop2000s[state_pop2000s['ages'] != "under18"]
state_pop2000s = state_pop2000s[state_pop2000s['state/region'] != "USA"]
state_pop2000s = state_pop2000s[state_pop2000s['state/region'] != "PR"]
state_pop2000s = state_pop2000s[state_pop2000s['state/region'] != "DC"]
state_pop2000s = state_pop2000s[state_pop2000s['year'] >= 1999]
state_pop2000s = state_pop2000s[state_pop2000s['year'] <= 2009]
state_pop2000s = state_pop2000s.rename(columns={"year": "Year", "population": "Population", "state/region": "Location"})
state_pop2000s.drop(["ages"], axis=1, inplace=True)

state_pop2000s.sort_index(inplace=True)
state_pop_melted = pd.melt(state_pop1019, id_vars=["Location"], var_name="Year", value_name="Population")

state_pop_melted.index = state_pop_melted.index.astype(int)
state_pop_melted['Year'] = state_pop_melted['Year'].astype(int)
state_pop2000s.columns.sort_values()
state_pop2000s.reset_index(inplace=True)
state_pop2000s.drop(["index"], axis=1, inplace=True)
# state_pop2000s.to_csv("state_pop2000s.csv")
# state_pop_melted.to_csv("state_pop_melted.csv")
combined_pop = pd.concat([state_pop2000s, state_pop_melted], ignore_index=True)
for year in range(2020, 2022):  # Add data for 2020 and 2021
    new_data = combined_pop.loc[combined_pop['Year'] == 2019].copy()
    new_data['Year'] = year
    combined_pop = pd.concat([combined_pop, new_data], ignore_index=True)

# Optional: Sort the DataFrame by Year and Location
combined_pop.sort_values(by=['Year', 'Location'], inplace=True)

# Reset the index if needed
combined_pop.reset_index()
combined_pop
# Out:
#      Location  Year  Population
# 11         AK  1999    624779.0
# 9          AL  1999   4430141.0
# 34         AR  1999   2651860.0
# 31         AZ  1999   5023823.0
# 53         CA  1999  33499204.0
# ...       ...   ...         ...
# 1144       VT  2021    623989.0
# 1146       WA  2021   7614893.0
# 1148       WI  2021   5822434.0
# 1147       WV  2021   1792147.0
# 1149       WY  2021    578759.0
#
# [1150 rows x 3 columns]

# %%
suicides_by_age_state = pd.read_csv(r"../Resources/Clean/suicides_by_state_by_age_1999-2021.csv")
suicides_by_age_state_pop = suicides_by_age_state.merge(combined_pop, on=['Location', 'Year'], how='inner')
suicides_by_age_state_pop.set_index("Year", inplace=True)

age_groups = ['18 to 24', '25 to 34', '35 to 44', '45 to 54', '55+']

for age_group in age_groups:
    suicides_by_age_state_pop[f"Suicides per 100k ({age_group})"] = (suicides_by_age_state_pop[age_group] / suicides_by_age_state_pop["Population"]) * 100000

suicides_by_age_state_pop.rename(columns={"18 to 24": "Total Suicides (18 to 24)", "25 to 34": "Total Suicides (25 to 34)", "35 to 44": "Total Suicides (35 to 44)", "45 to 54": "Total Suicides (45 to 54)", "55+": "Total Suicides (55+)"}, inplace=True)
suicides_by_age_state_pop.drop(["Total"], axis=1, inplace=True)
# Assuming your DataFrame is named df
column_to_move = "Population"
current_index = suicides_by_age_state_pop.columns.get_loc(column_to_move)

# Move the column to the 2nd position (index 1)
suicides_by_age_state_pop.insert(1, column_to_move, suicides_by_age_state_pop.pop(column_to_move))
suicides_by_age_state_pop
# suicides_by_age_state_pop.to_csv("suicides_by_age_state_pop.csv")

suicides_by_age_state_pop.max(axis=0)
# Out:
# Location                                WY
# Population                      39512223.0
# Total Suicides (18 to 24)            571.0
# Total Suicides (25 to 34)            824.0
# Total Suicides (35 to 44)            722.0
# Total Suicides (45 to 54)            967.0
# Total Suicides (55+)                1767.0
# Suicides per 100k (18 to 24)       6.83485
# Suicides per 100k (25 to 34)      7.518334
# Suicides per 100k (35 to 44)      7.108244
# Suicides per 100k (45 to 54)      6.940769
# Suicides per 100k (55+)          12.069859
# dtype: object

# %%
# Extracting US suicides from World suicides

world_suicides = pd.read_csv(r"../Resources/Originals/world_suicides_1985-2016.csv")
world_suicides.drop(["Population", "Country-Year"], axis=1, inplace=True)
us_suicides_8516 = world_suicides[world_suicides["Country"] == "United States"].copy()
# us_suicides_8516.to_csv("us_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for the US from 1985-2013

us_suicides_8513 = us_suicides_8516.drop(
    [
        "Sex",
        "Age",
        "Suicides per 100k",
        "GDP for Year ($)",
        "GDP per Capita ($)",
        "Generation",
    ],
    axis=1,
)
us_suicides_8513 = (
    us_suicides_8513.groupby("Year")["Number of Suicides"].sum().reset_index()
)
us_suicides_8513 = us_suicides_8513[
    ~((us_suicides_8513["Year"] == 2014) | (us_suicides_8513["Year"] == 2015))
]

# Extracting US suicide rates from World suicides

us_suicide_rates_8516 = world_suicides[
    world_suicides["Country"] == "United States"
].copy()
us_suicide_rates_8516 = (
    us_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
us_suicide_rates_8516["Country"] = "United States"
us_suicide_rates_8516 = us_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# us_suicide_rates_8516.to_csv("us_suicide_rates_1985-2016.csv", index=False)

# Extracting US suicide rates from World suicides (1999-2016)

excluded_years = [
    1985,
    1986,
    1987,
    1988,
    1989,
    1990,
    1991,
    1992,
    1993,
    1994,
    1995,
    1996,
    1997,
    1998,
]
us_suicide_rates_8516 = world_suicides[
    world_suicides["Country"] == "United States"
].copy()
us_suicide_rates_8516 = (
    us_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
us_suicide_rates_8516 = us_suicide_rates_8516[
    ~us_suicide_rates_8516["Year"].isin(excluded_years)
]
us_suicide_rates_8516["Country"] = "United States"
us_suicide_rates_8516 = us_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# us_suicide_rates_8516.to_csv("us_suicide_rates_1999-2016.csv", index=False)

# %%
# Extracting yearly total suicides for the US from 2014-2021

state_suicides_0521 = pd.read_csv(
    r"../Resources/Originals/state_suicides_2005-2021.csv"
)
state_suicides_0521.drop(["URL", "RATE"], axis=1, inplace=True)
state_suicides_0521["DEATHS"] = state_suicides_0521["DEATHS"].str.replace(",", "")
state_suicides_0521["DEATHS"] = state_suicides_0521["DEATHS"].str.replace('"', "")
state_suicides_0521["DEATHS"] = pd.to_numeric(
    state_suicides_0521["DEATHS"], errors="coerce"
)
us_suicides_0521 = state_suicides_0521.groupby("YEAR")["DEATHS"].sum().reset_index()
us_suicides_0521 = us_suicides_0521[~(us_suicides_0521["YEAR"] == 2005)]
column_mapping = {"YEAR": "Year", "DEATHS": "Number of Suicides"}
us_suicides_0521 = us_suicides_0521.rename(columns=column_mapping)

# %%
# Concatenating the dataframes to account for missing data

us_suicides_8521 = pd.concat([us_suicides_8513, us_suicides_0521]).reset_index()
us_suicides_8521["Country"] = "United States"
us_suicides_8521 = us_suicides_8521[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# us_suicides_8521.to_csv("us_suicides_1985-2021.csv", index=False)

# %%
# Sorting total suicides per 100k by country in descending order

world_suicide_rates_total = world_suicides.copy()

world_suicide_rates_total = world_suicide_rates_total.drop(
    ["Sex", "Age", "GDP for Year ($)", "GDP per Capita ($)", "Generation"], axis=1
)
world_suicide_rates_total = (
    world_suicide_rates_total.groupby("Country")["Suicides per 100k"]
    .sum()
    .reset_index()
)
world_suicide_rates_total.sort_values(
    "Suicides per 100k", ascending=False, inplace=True
)

# Establishing upper and lower quantiles

qlow_total = world_suicide_rates_total["Suicides per 100k"].quantile(0.02)
qhigh_total = world_suicide_rates_total["Suicides per 100k"].quantile(1)
total_filtered = world_suicide_rates_total[
    (world_suicide_rates_total["Suicides per 100k"] >= qlow_total)
    & (world_suicide_rates_total["Suicides per 100k"] <= qhigh_total)
]

# Extracting top 10 and bottom 10 countries by suicides per 100k

top_10_world_suicides_rates = total_filtered.head(10)
bottom_10_world_suicides_rates = total_filtered.tail(10)

# %%
# Extracting Russia suicides from World suicides

russia_suicides_8516 = world_suicides[
    world_suicides["Country"] == "Russian Federation"
].copy()
# russia_suicides_8516.to_csv("russia_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for Russia from 1985-2016

russia_suicides_8516 = (
    russia_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
)
russia_suicides_8516["Country"] = "Russia"
russia_suicides_8516 = russia_suicides_8516[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# russia_suicides_8516.to_csv("russia_suicides_1985-2016.csv", index=False)

# Extracting Russia suicide rates from World suicides

russia_suicide_rates_8516 = world_suicides[
    world_suicides["Country"] == "Russian Federation"
].copy()
russia_suicide_rates_8516 = (
    russia_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
russia_suicide_rates_8516["Country"] = "Russia"
russia_suicide_rates_8516 = russia_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# russia_suicide_rates_8516.to_csv("russia_suicide_rates_1985-2016.csv", index=False)

# %%
# Extracting South Korea suicides from World suicides

south_korea_suicides_8516 = world_suicides[
    world_suicides["Country"] == "Republic of Korea"
].copy()
# south_korea_suicides_8516.to_csv("south_korea_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for South Korea from 1985-2016

south_korea_suicides_8516 = (
    south_korea_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
)
south_korea_suicides_8516["Country"] = "South Korea"
south_korea_suicides_8516 = south_korea_suicides_8516[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# south_korea_suicides_8516.to_csv("south_korea_suicides_1985-2016.csv", index=False)

# Extracting South Korea suicide rates from World suicides

south_korea_suicide_rates_8516 = world_suicides[
    world_suicides["Country"] == "Republic of Korea"
].copy()
south_korea_suicide_rates_8516 = (
    south_korea_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
south_korea_suicide_rates_8516["Country"] = "South Korea"
south_korea_suicide_rates_8516 = south_korea_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# south_korea_suicide_rates_8516.to_csv(
#     "south_korea_suicide_rates_1985-2016.csv", index=False
# )

# %%
# Extracting Japan suicides from World suicides

japan_suicides_8516 = world_suicides[world_suicides["Country"] == "Japan"].copy()
# japan_suicides_8516.to_csv("japan_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for Japan from 1985-2016

japan_suicides_8516 = (
    japan_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
)
japan_suicides_8516["Country"] = "Japan"
japan_suicides_8516 = japan_suicides_8516[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# japan_suicides_8516.to_csv("japan_suicides_1985-2016.csv", index=False)

# Extracting Japan suicide rates from World suicides

japan_suicide_rates_8516 = world_suicides[world_suicides["Country"] == "Japan"].copy()
japan_suicide_rates_8516 = (
    japan_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
japan_suicide_rates_8516["Country"] = "Japan"
japan_suicide_rates_8516 = japan_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# japan_suicide_rates_8516.to_csv("japan_suicide_rates_1985-2016.csv", index=False)

# %%
# Extracting Paraguay suicides from World suicides

paraguay_suicides_8516 = world_suicides[world_suicides["Country"] == "Paraguay"].copy()
# paraguay_suicides_8516.to_csv("paraguay_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for Paraguay from 1985-2016

paraguay_suicides_8516 = (
    paraguay_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
)
paraguay_suicides_8516["Country"] = "Paraguay"
paraguay_suicides_8516 = paraguay_suicides_8516[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# paraguay_suicides_8516.to_csv("paraguay_suicides_1985-2016.csv", index=False)

# Extracting Paraguay suicide rates from World suicides

paraguay_suicide_rates_8516 = world_suicides[world_suicides["Country"] == "Paraguay"].copy()
paraguay_suicide_rates_8516 = (
    paraguay_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
paraguay_suicide_rates_8516["Country"] = "Paraguay"
paraguay_suicide_rates_8516 = paraguay_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# paraguay_suicide_rates_8516.to_csv("paraguay_suicide_rates_1985-2016.csv", index=False)

# %%
# Extracting Canada suicides from World suicides

canada_suicides_8516 = world_suicides[world_suicides["Country"] == "Canada"].copy()
# canada_suicides_8516.to_csv("canada_suicides_1985-2016(master).csv")

# Extracting yearly total suicides for Canada from 1985-2016

canada_suicides_8516 = (
    canada_suicides_8516.groupby("Year")["Number of Suicides"].sum().reset_index()
)
canada_suicides_8516["Country"] = "Canada"
canada_suicides_8516 = canada_suicides_8516[
    ["Country", "Year", "Number of Suicides"]
].reset_index(drop=True)
# canada_suicides_8516.to_csv("canada_suicides_1985-2016.csv", index=False)

# Extracting Canada suicide rates from World suicides

canada_suicide_rates_8516 = world_suicides[world_suicides["Country"] == "Canada"].copy()
canada_suicide_rates_8516 = (
    canada_suicide_rates_8516.groupby("Year")["Suicides per 100k"]
    .sum()
    .round(2)
    .reset_index()
)
canada_suicide_rates_8516["Country"] = "Canada"
canada_suicide_rates_8516 = canada_suicide_rates_8516[
    ["Country", "Year", "Suicides per 100k"]
].reset_index(drop=True)
# canada_suicide_rates_8516.to_csv("canada_suicide_rates_1985-2016.csv", index=False)

# %%
# Cleaning Untreated Mental Illness data

untreated_mental_illness = pd.read_csv(
    r"../Resources/Originals/untreated_mental_illness_in_adults_2018-2019.csv"
)
total_untreated_mental_illness = untreated_mental_illness[
    untreated_mental_illness["Location"] == "United States"
].copy()
states_untreated_mental_illness = untreated_mental_illness[
    ~(untreated_mental_illness["Location"] == "United States")
]
total_untreated_mental_illness.set_index("Location", inplace=True)
states_untreated_mental_illness.set_index("Location", inplace=True)
total_untreated_mental_illness = total_untreated_mental_illness * 100
total_untreated_mental_illness = total_untreated_mental_illness.round(2)
states_untreated_mental_illness = states_untreated_mental_illness * 100
states_untreated_mental_illness = states_untreated_mental_illness.round(2)
# total_untreated_mental_illness.to_csv("untreated_mental_illness_total_2018-2019.csv")
